# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# Define the possible values for each feature
customer_types = ["Corporate", "Institutional", "Government"]
industries = ["Finance", "Healthcare", "Technology", "Energy", "Manufacturing"]
locations = ["USA", "Europe", "Asia", "New York", "London", "Tokyo"]
relationship_managers = ["John Smith", "Jane Doe", "RM-001", "RM-002", "RM-003"]

product_types = ["Loan", "Deposit", "Trade Finance", "Cash Management", "Risk Management"]
product_categories = ["Cash Management", "Risk Management", "Trade Services", "Lending", "Investments"]
product_subcategories = ["Credit Facilities", "Foreign Exchange", "Supply Chain Finance", "Term Loans", "Commercial Cards"]
product_features = ["Interest Rate", "Tenor", "Currency", "Collateral", "Covenants"]

transaction_types = ["Loan Disbursement", "Deposit", "Trade Settlement", "Credit Facility", "FX Trade"]
currencies = ["USD", "EUR", "GBP", "JPY", "CHF"]

risk_ratings = ["Low", "Medium", "High"]
regulatory_requirements = ["KYC", "AML", "CCAR", "Basel III", "Dodd-Frank"]

# Define the synthetic data generation rules
def generate_customer_id():
    return f"CUS-{random.randint(1, 1000):03d}"

def generate_customer_type():
    return random.choice(customer_types)

def generate_industry():
    return random.choice(industries)

def generate_company_size():
    return random.randint(100, 10000)

def generate_location():
    return random.choice(locations)

def generate_relationship_manager():
    return random.choice(relationship_managers)

def generate_product_id():
    return f"PROD-{random.randint(1, 1000):03d}"

def generate_product_type():
    return random.choice(product_types)

def generate_product_category():
    return random.choice(product_categories)

def generate_product_subcategory():
    return random.choice(product_subcategories)

def generate_product_features():
    return random.choice(product_features)

def generate_transaction_id():
    return f"TRAN-{random.randint(1, 1000):03d}"

def generate_transaction_date():
    return datetime.now() - timedelta(days=random.randint(1, 365))

def generate_transaction_type():
    return random.choice(transaction_types)

def generate_transaction_amount():
    return random.uniform(1000.0, 100000.0)

def generate_transaction_currency():
    return random.choice(currencies)

def generate_transaction_frequency():
    return random.randint(1, 10)

def generate_transaction_value():
    return random.uniform(10000.0, 100000.0)

def generate_product_adoption():
    return random.randint(1, 5)

def generate_product_usage():
    return random.randint(1, 10)

def generate_customer_engagement():
    return random.randint(1, 10)

def generate_credit_score():
    return random.uniform(600.0, 800.0)

def generate_risk_rating():
    return random.choice(risk_ratings)

def generate_default_probability():
    return random.uniform(0.01, 0.10)

def generate_exposure():
    return random.uniform(10000.0, 100000.0)

def generate_market_data():
    return random.uniform(100.0, 1000.0)

def generate_economic_indicators():
    return random.uniform(2.0, 4.0)

def generate_regulatory_requirements():
    return random.choice(regulatory_requirements)

# Generate the synthetic data
data = []
for i in range(1000):
    customer_id = generate_customer_id()
    customer_type = generate_customer_type()
    industry = generate_industry()
    company_size = generate_company_size()
    location = generate_location()
    relationship_manager = generate_relationship_manager()
    
    product_id = generate_product_id()
    product_type = generate_product_type()
    product_category = generate_product_category()
    product_subcategory = generate_product_subcategory()
    product_features = generate_product_features()
    
    transaction_id = generate_transaction_id()
    transaction_date = generate_transaction_date()
    transaction_type = generate_transaction_type()
    transaction_amount = generate_transaction_amount()
    transaction_currency = generate_transaction_currency()
    
    transaction_frequency = generate_transaction_frequency()
    transaction_value = generate_transaction_value()
    product_adoption = generate_product_adoption()
    product_usage = generate_product_usage()
    customer_engagement = generate_customer_engagement()
    
    credit_score = generate_credit_score()
    risk_rating = generate_risk_rating()
    default_probability = generate_default_probability()
    exposure = generate_exposure()
    
    market_data = generate_market_data()
    economic_indicators = generate_economic_indicators()
    regulatory_requirements = generate_regulatory_requirements()
    
    data.append({
        "Customer ID": customer_id,
        "Customer Type": customer_type,
        "Industry": industry,
        "Company Size": company_size,
        "Location": location,
        "Relationship Manager": relationship_manager,
        
        "Product ID": product_id,
        "Product Type": product_type,
        "Product Category": product_category,
        "Product Subcategory": product_subcategory,
        "Product Features": product_features,
        
        "Transaction ID": transaction_id,
        "Transaction Date": transaction_date,
        "Transaction Type": transaction_type,
        "Transaction Amount": transaction_amount,
        "Transaction Currency": transaction_currency,
        
        "Transaction Frequency": transaction_frequency,
        "Transaction Value": transaction_value,
        "Product Adoption": product_adoption,
        "Product Usage": product_usage,
        "Customer Engagement": customer_engagement,
        
        "Credit Score": credit_score,
        "Risk Rating": risk_rating,
        "Default Probability": default_probability,
        "Exposure": exposure,
        
        "Market Data": market_data,
        "Economic Indicators": economic_indicators,
        "Regulatory Requirements": regulatory_requirements
    })

# Create a Pandas DataFrame from the synthetic data
df = pd.DataFrame(data)

# Save the synthetic data to a CSV file
df.to_csv("wholesale_banking_synthetic_data.csv", index=False)

print(df.head())
# Out:
#   Customer ID  Customer Type       Industry  Company Size Location  \
# 0     CUS-398      Corporate  Manufacturing          1188      USA
# 1     CUS-643  Institutional  Manufacturing          2223   London
# 2     CUS-460  Institutional        Finance          5260   London
# 3     CUS-257      Corporate        Finance          2176      USA
# 4     CUS-283  Institutional     Healthcare          3475     Asia
#
#   Relationship Manager Product ID     Product Type Product Category  \
# 0               RM-003   PROD-220  Risk Management          Lending
# 1           John Smith   PROD-326          Deposit          Lending
# 2               RM-002   PROD-083    Trade Finance      Investments
# 3               RM-002   PROD-079  Risk Management          Lending
# 4               RM-001   PROD-018          Deposit      Investments
#
#     Product Subcategory  ... Product Adoption Product Usage  \
# 0      Commercial Cards  ...                4             9
# 1      Commercial Cards  ...                3             3
# 2            Term Loans  ...                4             8
# 3  Supply Chain Finance  ...                3            10
# 4     Credit Facilities  ...                5             9
#
#   Customer Engagement Credit Score  Risk Rating Default Probability  \
# 0                   6   711.255870       Medium            0.047315
# 1                   8   769.313067         High            0.053878
# 2                   4   602.909159         High            0.026782
# 3                   2   620.430112         High            0.094926
# 4                   3   748.550629       Medium            0.012543
#
#        Exposure  Market Data  Economic Indicators  Regulatory Requirements
# 0  71493.620077   296.058554             3.677482                     CCAR
# 1  47165.315362   339.410544             2.657077                        C
# 2  39693.048809   839.954963             3.898175                        C
# 3  34451.894554   743.570909             3.360672                        C
# 4  47900.882838   558.265576             3.408090                        C
#
# [5 rows x 28 columns]

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
from torch_geometric.utils import to_networkx
import networkx as nx
import pyvis
from pyvis.network import Network

# Load the synthetic data
df = pd.read_csv("wholesale_banking_synthetic_data.csv")

# Define the task: Product Recommendation
task = "Product Recommendation"

print(f"Task: {task}")

# Build the graph
customer_ids = df["Customer ID"].unique()
product_ids = df["Product ID"].unique()

customer_id_map = {id: i for i, id in enumerate(customer_ids)}
product_id_map = {id: i + len(customer_ids) for i, id in enumerate(product_ids)}

edges = []
for index, row in df.iterrows():
    customer_id = row["Customer ID"]
    product_id = row["Product ID"]
    edges.append((customer_id_map[customer_id], product_id_map[product_id]))

# Create a node feature matrix (x) with random values
x = torch.randn(len(customer_ids) + len(product_ids), 64)

# Create the edge index tensor
edge_index = torch.tensor(edges).t().contiguous()

# Create the graph data object
graph = Data(x=x, edge_index=edge_index)

print("Graph built with", len(customer_ids), "customers and", len(product_ids), "products")

#...

# Visualize the graph
nx_graph = to_networkx(graph)
net = Network("500px", "500px")
net.from_nx(nx_graph)

# Add node labels
node_labels = {}
for node in nx_graph.nodes:
    if node < len(customer_ids):
        customer_id = customer_ids[node]
        customer_type = df.loc[df["Customer ID"] == customer_id, "Customer Type"].iloc[0]
        industry = df.loc[df["Customer ID"] == customer_id, "Industry"].iloc[0]
        node_labels[node] = f"Customer {customer_id} ({customer_type}, {industry})"
    else:
        product_id = product_ids[node - len(customer_ids)]
        product_type = df.loc[df["Product ID"] == product_id, "Product Type"].iloc[0]
        product_category = df.loc[df["Product ID"] == product_id, "Product Category"].iloc[0]
        node_labels[node] = f"Product {product_id} ({product_type}, {product_category})"

for node, label in node_labels.items():
    net.nodes[node]['label'] = label

# Add edge labels
edge_labels = {}
for i, edge in enumerate(nx_graph.edges):
    transaction_type = df.loc[(df["Customer ID"] == customer_ids[edge[0]]) & (df["Product ID"] == product_ids[edge[1] - len(customer_ids)]), "Transaction Type"].iloc[0]
    edge_labels[edge] = transaction_type

for i, edge in enumerate(nx_graph.edges):
    net.edges[i]['label'] = edge_labels[edge]

net.repulsion(node_distance=420, spring_length=200)
net.show_buttons(filter_=['physics'])
net.save_graph("graph.html")

print("Graph saved to graph.html")
# Out:
# Task: Product Recommendation
# Graph built with 631 customers and 639 products
# Graph saved to graph.html

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
from torch_geometric.utils import to_networkx
import networkx as nx
import pyvis
from pyvis.network import Network

# Load the synthetic data
df = pd.read_csv("wholesale_banking_synthetic_data.csv")

# Define the task: Product Recommendation
task = "Product Recommendation"

print(f"Task: {task}")
# Build the graph
customer_ids = df["Customer ID"].unique()
product_ids = df["Product ID"].unique()

customer_id_map = {id: i for i, id in enumerate(customer_ids)}
product_id_map = {id: i for i, id in enumerate(product_ids)}

edges = []
for index, row in df.iterrows():
    customer_id = row["Customer ID"]
    product_id = row["Product ID"]
    edges.append((customer_id_map[customer_id], product_id_map[product_id]))
# Create a node feature matrix (x) with random values
x = torch.randn(len(customer_ids) + len(product_ids), 64)
y = torch.randint(0, 32, (100,))
graph = Data(x=torch.randn(100, 64), edge_index=torch.tensor([[0, 1, 1, 2], [1, 0, 2, 1]]), y=y)


print("Graph built with", len(customer_ids), "customers and", len(product_ids), "products")

# # Visualize the graph
# nx_graph = to_networkx(graph)
# net = Network("500px", "500px")
# net.from_nx(nx_graph)
# net.repulsion(node_distance=420, spring_length=200)
# net.show_buttons(filter_=['physics'])
# net.save_graph("graph.html")

# print("Graph saved to graph.html")

# Design the model
class GATModel(nn.Module):
    def __init__(self, num_layers, hidden_dim, output_dim):
        super(GATModel, self).__init__()
        self.layers = nn.ModuleList([GATConv(hidden_dim, hidden_dim) for _ in range(num_layers)])
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x, edge_index):
        for layer in self.layers:
            x = layer(x, edge_index)
        x = self.fc(x)
        return x

model = GATModel(num_layers=2, hidden_dim=64, output_dim=32)
# Check if graph.x and graph.edge_index are not None
if graph.x is not None and graph.edge_index is not None:
    out = model(graph.x, graph.edge_index)
    print(out)
else:
    print("Error: graph.x or graph.edge_index is None")

print("Model designed")

# Train the model
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

for epoch in range(10):
    optimizer.zero_grad()
    out = model(graph.x, graph.edge_index)
    loss = criterion(out, graph.y)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")

print("Model trained")

# Seasonality
# Not applicable in this case, as we don't have temporal data

# Hyperparameter tuning
# Not implemented in this example, but can be done using techniques like grid search or random search

# Results
print("Results:")
print("Model performance on training data:")
print("Loss:", loss.item())

# Next avenues
print("Next avenues:")
print("1. Incorporate additional customer and product features")
print("2. Experiment with different GAT architectures and hyperparameters")
print("3. Evaluate model performance on a held-out test set")

# Conclusion
print("Conclusion:")
print("We have built a GAT-based product recommendation engine using PyTorch Geometric and PyVis libraries")
print("The model has been trained on the synthetic data and achieved a loss of", loss.item())
print("Future work includes incorporating additional features, experimenting with different architectures, and evaluating model performance on a held-out test set")
# Out:
# Task: Product Recommendation
# Graph built with 631 customers and 639 products
# tensor([[ 0.0517, -0.3617, -0.0932,  ..., -0.0204, -0.4957, -0.0680],
#         [ 0.0998, -0.3700, -0.2709,  ...,  0.0958, -0.3957, -0.3087],
#         [ 0.1194, -0.3782, -0.3742,  ...,  0.1339, -0.3523, -0.4687],
#         ...,
#         [ 0.2093, -0.2173,  0.3320,  ...,  0.2393,  0.5139, -1.0374],
#         [-0.2818,  0.9832, -0.0351,  ..., -0.1330,  0.3367, -0.3189],
#         [-0.3418, -0.8945, -0.0643,  ...,  0.3097, -0.0762,  0.5758]],
#        grad_fn=<AddmmBackward0>)
# Model designed
# Epoch 1, Loss: 3.6428661346435547
# Epoch 2, Loss: 2.952962636947632
# Epoch 3, Loss: 2.356222152709961
# Epoch 4, Loss: 1.8206771612167358
# Epoch 5, Loss: 1.3524361848831177
# Epoch 6, Loss: 0.9633511304855347
# Epoch 7, Loss: 0.6464270949363708
# Epoch 8, Loss: 0.3995788097381592
# Epoch 9, Loss: 0.23082104325294495
# Epoch 10, Loss: 0.12499009072780609
# Model trained
# Results:
# Model performance on training data:
# Loss: 0.12499009072780609
# Next avenues:
# 1. Incorporate additional customer and product features
# 2. Experiment with different GAT architectures and hyperparameters
# 3. Evaluate model performance on a held-out test set
# Conclusion:
# We have built a GAT-based product recommendation engine using PyTorch Geometric and PyVis libraries
# The model has been trained on the synthetic data and achieved a loss of 0.12499009072780609
# Future work includes incorporating additional features, experimenting with different architectures, and evaluating model performance on a held-out test set

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Assuming you have a test dataset with features (x_test) and ground truth labels (y_test)
# Make predictions
with torch.no_grad():
    model.eval()
    y_pred = model(graph.x, graph.edge_index)

# Convert predicted probabilities to class labels
y_pred_labels = y_pred.argmax(dim=1)

# Convert ground truth to numpy array
y_true = graph.y.numpy()

# Calculate evaluation metrics
accuracy = accuracy_score(y_true, y_pred_labels)
precision = precision_score(y_true, y_pred_labels, average='macro')  # Can change average parameter as needed
recall = recall_score(y_true, y_pred_labels, average='macro')  # Can change average parameter as needed
f1 = f1_score(y_true, y_pred_labels, average='macro')  # Can change average parameter as needed

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.99
# Precision: 0.9933333333333334
# Recall: 0.9952380952380953
# F1-score: 0.9937321937321938

# %%
import numpy as np
from sklearn.cluster import KMeans

# Assuming 'out' contains the embeddings from the GAT model
customer_embeddings = out[:len(customer_ids), :]

# Applying K-means clustering to customer embeddings
n_clusters = 5  # Define the number of segments you want to create
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(customer_embeddings.detach().numpy())

# Assign clusters to each customer
clusters = kmeans.labels_

# Map clusters back to customer IDs
customer_cluster_map = {customer_ids[i]: cluster for i, cluster in enumerate(clusters)}

# Display customer segments
for cluster_id in range(n_clusters):
    print(f"Customers in segment {cluster_id}:")
    members = [cid for cid, clust in customer_cluster_map.items() if clust == cluster_id]
    print(members)

# Optional: Analyze cluster contents or centroids
centroids = kmeans.cluster_centers_
print("Cluster centroids:")
print(centroids)
# Out:
# Customers in segment 0:
# ['CUS-901', 'CUS-537', 'CUS-441', 'CUS-811', 'CUS-952', 'CUS-322', 'CUS-374', 'CUS-647', 'CUS-022', 'CUS-290', 'CUS-835', 'CUS-461', 'CUS-774', 'CUS-563', 'CUS-375', 'CUS-059', 'CUS-199']
# Customers in segment 1:
# ['CUS-283', 'CUS-615', 'CUS-474', 'CUS-822', 'CUS-372', 'CUS-103', 'CUS-427', 'CUS-477', 'CUS-014', 'CUS-551', 'CUS-796', 'CUS-947', 'CUS-052', 'CUS-577', 'CUS-648', 'CUS-550']
# Customers in segment 2:
# ['CUS-030', 'CUS-308', 'CUS-903', 'CUS-154', 'CUS-007', 'CUS-712', 'CUS-129', 'CUS-749', 'CUS-846', 'CUS-562', 'CUS-471', 'CUS-817', 'CUS-974', 'CUS-599', 'CUS-105', 'CUS-870', 'CUS-425', 'CUS-243', 'CUS-799', 'CUS-098', 'CUS-378', 'CUS-544', 'CUS-260', 'CUS-825', 'CUS-741', 'CUS-483', 'CUS-726', 'CUS-757', 'CUS-079']
# Customers in segment 3:
# ['CUS-257', 'CUS-753', 'CUS-438', 'CUS-175', 'CUS-405', 'CUS-618', 'CUS-317', 'CUS-360', 'CUS-978', 'CUS-914', 'CUS-758', 'CUS-699', 'CUS-511', 'CUS-458', 'CUS-173', 'CUS-868', 'CUS-258', 'CUS-675', 'CUS-080']
# Customers in segment 4:
# ['CUS-398', 'CUS-643', 'CUS-460', 'CUS-936', 'CUS-012', 'CUS-590', 'CUS-608', 'CUS-227', 'CUS-808', 'CUS-202', 'CUS-361', 'CUS-709', 'CUS-684', 'CUS-778', 'CUS-594', 'CUS-827', 'CUS-274', 'CUS-381', 'CUS-473']
# Cluster centroids:
# [[-1.22970116e+00 -1.40462613e+00  1.54337800e+00  1.48176503e+00
#    4.66396284e+00 -1.40410364e-01 -1.64263952e+00  3.41723990e+00
#    2.21234059e+00 -8.56863618e-01 -1.82549953e+00  1.32450390e+00
#   -2.30810785e+00 -1.45773852e+00 -1.76122814e-01  1.25517464e+00
#    2.17364693e+00 -4.17237091e+00 -2.53831744e+00  6.75956726e-01
#   -1.81972623e+00 -4.51748371e+00 -2.81232071e+00 -3.21534204e+00
#    2.20630836e+00 -1.50991738e-01  8.22314322e-01 -1.14007616e+00
#    1.75712466e+00  1.94620341e-03 -1.30690837e+00  2.17835593e+00]
#  [-6.32823467e-01 -1.95288920e+00  2.56715250e+00 -1.39002466e+00
#   -1.66823590e+00  2.22899389e+00  7.06005871e-01 -1.34150362e+00
#   -2.31300044e+00 -2.23757803e-01  3.42703724e+00 -5.65011859e-01
#    1.72797251e+00  5.92519403e-01 -1.32557702e+00 -1.49032563e-01
#    1.93997288e+00  7.09719121e-01  1.95976758e+00  1.30085826e+00
#   -1.42289412e+00  1.81950712e+00 -2.77638853e-01  7.96281695e-01
#   -2.37545013e+00 -9.38002408e-01 -1.37433767e+00 -5.81379592e-01
#    1.65762269e+00 -1.66841775e-01 -7.34167516e-01 -9.37346667e-02]
#  [-3.86633933e-01  3.02964044e+00 -1.07170925e-01 -1.59031391e-01
#    2.70494312e-01 -1.40003371e+00  3.99795234e-01 -1.72762585e+00
#   -1.30359149e+00 -5.10386884e-01 -2.47820377e+00 -1.55839324e-02
#   -8.43331814e-02 -1.27799821e+00  7.44871020e-01  1.17119694e+00
#   -2.14804506e+00  3.66094851e+00  1.85441232e+00  7.20115840e-01
#    5.53547978e-01  2.54546225e-01 -1.42537266e-01  2.94989800e+00
#    4.23903227e-01  7.56487846e-01 -2.17504099e-01 -1.92455697e+00
#   -7.16695428e-01  2.16945839e+00  1.25897610e+00 -1.82047284e+00]
#  [-2.01031399e+00 -1.11228466e+00 -1.27513781e-01 -1.69642723e+00
#   -1.94108200e+00  3.32579947e+00 -2.97101164e+00  2.91639507e-01
#    8.56649101e-01 -1.26671124e+00  3.41982174e+00 -9.68750954e-01
#   -1.85922253e+00 -5.12942791e-01  1.86010909e+00 -1.54972363e+00
#    1.04152894e+00 -2.74262094e+00 -2.61643529e+00  7.47319579e-01
#    1.28405404e+00 -1.41131556e+00 -4.58330363e-01 -2.31727690e-01
#    3.33272338e+00 -1.77934873e+00 -3.33275110e-01  2.38083869e-01
#   -8.54303777e-01 -1.67061102e+00 -1.68682146e+00  1.44496608e+00]
#  [-5.97238839e-01 -3.43791425e-01 -2.16605353e+00 -2.23748636e+00
#   -1.61455378e-01  6.54737949e-02  2.06591249e+00  2.21224141e+00
#    3.81988645e-01 -6.55042589e-01  1.81004405e+00 -1.85883164e+00
#   -7.79204130e-01 -6.45798147e-01 -1.47523117e+00 -1.02572292e-01
#   -2.09265143e-01 -9.53125834e-01  1.18263984e+00 -1.41771185e+00
#    1.61975592e-01  2.26511550e+00  1.07420945e+00 -3.81669074e-01
#   -3.24338675e-01 -2.39142179e+00 -6.33588970e-01  5.09084606e+00
#   -1.75406194e+00 -8.62557292e-01  2.87045121e-01  7.61922225e-02]]

# %%
import torch

def print_business_insights(model, customer_ids, product_ids, edge_index, num_recommendations=5):
    # Ensure the model is in evaluation mode
    model.eval()
    
    # Run the model to get predictions with no gradient calculations
    with torch.no_grad():
        predictions = model(graph.x, edge_index)
    
    # Convert predictions to probabilities using softmax
    probabilities = torch.softmax(predictions, dim=1)
    
    # Safety check to ensure the slice does not go out of bounds
    max_idx = min(len(customer_ids), probabilities.shape[0])
    
    # Extract predictions for customers
    customer_predictions = probabilities[:max_idx]
    
    # For each customer, get the top recommended products
    for idx, customer_id in enumerate(customer_ids[:max_idx]):
        customer_prob = customer_predictions[idx]
        top_products = torch.topk(customer_prob, k=min(num_recommendations, customer_prob.size(0)))
        
        # Map product indices back to product IDs, checking bounds
        top_product_ids = [product_ids[i] for i in top_products.indices if i < len(product_ids)]
        
        # Print the results
        print(f"Top {num_recommendations} recommendations for Customer ID {customer_id}:")
        for product_id in top_product_ids:
            product_index = product_id_map[product_id]
            print(f"- {product_id} with probability {customer_prob[product_index]:.4f}")

# Assuming the model, graph, customer_id_map, and product_id_map are already defined and available
print_business_insights(model, list(customer_id_map.keys()), list(product_id_map.keys()), graph.edge_index)
# Out:
# Top 5 recommendations for Customer ID CUS-398:
# - PROD-700 with probability 0.5615
# - PROD-406 with probability 0.1001
# - PROD-429 with probability 0.0696
# - PROD-130 with probability 0.0483
# - PROD-018 with probability 0.0359
# Top 5 recommendations for Customer ID CUS-643:
# - PROD-406 with probability 0.3745
# - PROD-429 with probability 0.2995
# - PROD-700 with probability 0.1273
# - PROD-018 with probability 0.0450
# - PROD-130 with probability 0.0332
# Top 5 recommendations for Customer ID CUS-460:
# - PROD-406 with probability 0.4683
# - PROD-429 with probability 0.3937
# - PROD-018 with probability 0.0303
# - PROD-700 with probability 0.0299
# - PROD-340 with probability 0.0181
# Top 5 recommendations for Customer ID CUS-257:
# - PROD-838 with probability 0.9814
# - PROD-340 with probability 0.0104
# - PROD-331 with probability 0.0030
# - PROD-700 with probability 0.0015
# - PROD-429 with probability 0.0008
# Top 5 recommendations for Customer ID CUS-283:
# - PROD-158 with probability 0.9642
# - PROD-900 with probability 0.0171
# - PROD-331 with probability 0.0072
# - PROD-340 with probability 0.0071
# - PROD-405 with probability 0.0009
# Top 5 recommendations for Customer ID CUS-901:
# - PROD-303 with probability 0.9988
# - PROD-156 with probability 0.0003
# - PROD-018 with probability 0.0002
# - PROD-405 with probability 0.0001
# - PROD-083 with probability 0.0001
# Top 5 recommendations for Customer ID CUS-537:
# - PROD-018 with probability 0.9999
# - PROD-326 with probability 0.0000
# - PROD-130 with probability 0.0000
# - PROD-429 with probability 0.0000
# - PROD-303 with probability 0.0000
# Top 5 recommendations for Customer ID CUS-441:
# - PROD-904 with probability 0.9904
# - PROD-747 with probability 0.0049
# - PROD-331 with probability 0.0011
# - PROD-936 with probability 0.0010
# - PROD-377 with probability 0.0009
# Top 5 recommendations for Customer ID CUS-753:
# - PROD-377 with probability 0.8898
# - PROD-340 with probability 0.0641
# - PROD-838 with probability 0.0131
# - PROD-429 with probability 0.0061
# - PROD-951 with probability 0.0060
# Top 5 recommendations for Customer ID CUS-936:
# - PROD-429 with probability 0.9945
# - PROD-340 with probability 0.0014
# - PROD-156 with probability 0.0014
# - PROD-303 with probability 0.0010
# - PROD-406 with probability 0.0007
# Top 5 recommendations for Customer ID CUS-012:
# - PROD-156 with probability 0.9629
# - PROD-303 with probability 0.0124
# - PROD-018 with probability 0.0091
# - PROD-429 with probability 0.0054
# - PROD-587 with probability 0.0019
# Top 5 recommendations for Customer ID CUS-590:
# - PROD-340 with probability 0.8692
# - PROD-303 with probability 0.0169
# - PROD-377 with probability 0.0117
# - PROD-904 with probability 0.0100
# - PROD-018 with probability 0.0091
# Top 5 recommendations for Customer ID CUS-608:
# - PROD-429 with probability 0.9866
# - PROD-303 with probability 0.0071
# - PROD-405 with probability 0.0023
# - PROD-156 with probability 0.0013
# - PROD-331 with probability 0.0005
# Top 5 recommendations for Customer ID CUS-615:
# - PROD-331 with probability 0.9906
# - PROD-158 with probability 0.0036
# - PROD-198 with probability 0.0021
# - PROD-900 with probability 0.0006
# - PROD-447 with probability 0.0005
# Top 5 recommendations for Customer ID CUS-030:
# - PROD-838 with probability 0.9741
# - PROD-951 with probability 0.0085
# - PROD-303 with probability 0.0044
# - PROD-393 with probability 0.0038
# - PROD-471 with probability 0.0026
# Top 5 recommendations for Customer ID CUS-308:
# - PROD-406 with probability 0.9960
# - PROD-587 with probability 0.0020
# - PROD-156 with probability 0.0012
# - PROD-900 with probability 0.0004
# - PROD-326 with probability 0.0002
# Top 5 recommendations for Customer ID CUS-227:
# - PROD-429 with probability 0.9812
# - PROD-900 with probability 0.0080
# - PROD-936 with probability 0.0073
# - PROD-331 with probability 0.0011
# - PROD-377 with probability 0.0004
# Top 5 recommendations for Customer ID CUS-903:
# - PROD-326 with probability 0.9907
# - PROD-406 with probability 0.0036
# - PROD-156 with probability 0.0023
# - PROD-587 with probability 0.0016
# - PROD-018 with probability 0.0011
# Top 5 recommendations for Customer ID CUS-154:
# - PROD-018 with probability 0.9857
# - PROD-303 with probability 0.0030
# - PROD-447 with probability 0.0020
# - PROD-471 with probability 0.0019
# - PROD-951 with probability 0.0018
# Top 5 recommendations for Customer ID CUS-474:
# - PROD-340 with probability 0.7923
# - PROD-405 with probability 0.0816
# - PROD-951 with probability 0.0253
# - PROD-406 with probability 0.0234
# - PROD-900 with probability 0.0129
# Top 5 recommendations for Customer ID CUS-822:
# - PROD-340 with probability 0.9596
# - PROD-405 with probability 0.0260
# - PROD-900 with probability 0.0027
# - PROD-429 with probability 0.0020
# - PROD-997 with probability 0.0018
# Top 5 recommendations for Customer ID CUS-372:
# - PROD-156 with probability 0.9589
# - PROD-900 with probability 0.0091
# - PROD-083 with probability 0.0083
# - PROD-471 with probability 0.0081
# - PROD-158 with probability 0.0066
# Top 5 recommendations for Customer ID CUS-438:
# - PROD-198 with probability 0.9723
# - PROD-340 with probability 0.0134
# - PROD-700 with probability 0.0030
# - PROD-405 with probability 0.0028
# - PROD-747 with probability 0.0024
# Top 5 recommendations for Customer ID CUS-103:
# - PROD-340 with probability 0.9873
# - PROD-700 with probability 0.0079
# - PROD-156 with probability 0.0029
# - PROD-587 with probability 0.0006
# - PROD-429 with probability 0.0003
# Top 5 recommendations for Customer ID CUS-427:
# - PROD-156 with probability 0.9547
# - PROD-700 with probability 0.0277
# - PROD-340 with probability 0.0063
# - PROD-838 with probability 0.0044
# - PROD-198 with probability 0.0021
# Top 5 recommendations for Customer ID CUS-007:
# - PROD-331 with probability 0.9484
# - PROD-838 with probability 0.0107
# - PROD-447 with probability 0.0057
# - PROD-083 with probability 0.0049
# - PROD-747 with probability 0.0046
# Top 5 recommendations for Customer ID CUS-712:
# - PROD-018 with probability 0.9927
# - PROD-198 with probability 0.0048
# - PROD-326 with probability 0.0012
# - PROD-156 with probability 0.0003
# - PROD-158 with probability 0.0002
# Top 5 recommendations for Customer ID CUS-477:
# - PROD-997 with probability 0.9849
# - PROD-587 with probability 0.0041
# - PROD-900 with probability 0.0031
# - PROD-700 with probability 0.0021
# - PROD-083 with probability 0.0020
# Top 5 recommendations for Customer ID CUS-808:
# - PROD-429 with probability 0.9449
# - PROD-303 with probability 0.0461
# - PROD-340 with probability 0.0024
# - PROD-405 with probability 0.0013
# - PROD-377 with probability 0.0007
# Top 5 recommendations for Customer ID CUS-014:
# - PROD-900 with probability 0.9585
# - PROD-156 with probability 0.0291
# - PROD-340 with probability 0.0050
# - PROD-406 with probability 0.0034
# - PROD-429 with probability 0.0013
# Top 5 recommendations for Customer ID CUS-202:
# - PROD-900 with probability 0.9860
# - PROD-406 with probability 0.0052
# - PROD-429 with probability 0.0029
# - PROD-331 with probability 0.0026
# - PROD-326 with probability 0.0019
# Top 5 recommendations for Customer ID CUS-811:
# - PROD-303 with probability 0.9752
# - PROD-018 with probability 0.0086
# - PROD-951 with probability 0.0046
# - PROD-838 with probability 0.0029
# - PROD-936 with probability 0.0028
# Top 5 recommendations for Customer ID CUS-361:
# - PROD-303 with probability 0.9350
# - PROD-156 with probability 0.0432
# - PROD-083 with probability 0.0060
# - PROD-340 with probability 0.0043
# - PROD-951 with probability 0.0027
# Top 5 recommendations for Customer ID CUS-952:
# - PROD-838 with probability 0.9752
# - PROD-018 with probability 0.0067
# - PROD-393 with probability 0.0041
# - PROD-303 with probability 0.0024
# - PROD-079 with probability 0.0017
# Top 5 recommendations for Customer ID CUS-129:
# - PROD-747 with probability 0.9823
# - PROD-331 with probability 0.0047
# - PROD-130 with probability 0.0021
# - PROD-083 with probability 0.0019
# - PROD-198 with probability 0.0014
# Top 5 recommendations for Customer ID CUS-322:
# - PROD-079 with probability 0.9724
# - PROD-405 with probability 0.0055
# - PROD-130 with probability 0.0046
# - PROD-083 with probability 0.0043
# - PROD-158 with probability 0.0033
# Top 5 recommendations for Customer ID CUS-175:
# - PROD-838 with probability 0.9363
# - PROD-340 with probability 0.0491
# - PROD-198 with probability 0.0104
# - PROD-018 with probability 0.0013
# - PROD-951 with probability 0.0009
# Top 5 recommendations for Customer ID CUS-749:
# - PROD-587 with probability 0.9831
# - PROD-700 with probability 0.0089
# - PROD-326 with probability 0.0030
# - PROD-406 with probability 0.0014
# - PROD-377 with probability 0.0010
# Top 5 recommendations for Customer ID CUS-846:
# - PROD-700 with probability 0.8054
# - PROD-587 with probability 0.0934
# - PROD-747 with probability 0.0305
# - PROD-198 with probability 0.0298
# - PROD-156 with probability 0.0120
# Top 5 recommendations for Customer ID CUS-405:
# - PROD-331 with probability 0.5535
# - PROD-340 with probability 0.4190
# - PROD-747 with probability 0.0074
# - PROD-900 with probability 0.0053
# - PROD-405 with probability 0.0044
# Top 5 recommendations for Customer ID CUS-618:
# - PROD-331 with probability 0.9889
# - PROD-747 with probability 0.0033
# - PROD-198 with probability 0.0023
# - PROD-303 with probability 0.0022
# - PROD-936 with probability 0.0009
# Top 5 recommendations for Customer ID CUS-374:
# - PROD-158 with probability 0.9864
# - PROD-018 with probability 0.0050
# - PROD-198 with probability 0.0021
# - PROD-405 with probability 0.0017
# - PROD-083 with probability 0.0015
# Top 5 recommendations for Customer ID CUS-562:
# - PROD-700 with probability 0.9600
# - PROD-587 with probability 0.0307
# - PROD-471 with probability 0.0015
# - PROD-326 with probability 0.0012
# - PROD-156 with probability 0.0012
# Top 5 recommendations for Customer ID CUS-647:
# - PROD-018 with probability 0.9898
# - PROD-936 with probability 0.0033
# - PROD-429 with probability 0.0023
# - PROD-303 with probability 0.0013
# - PROD-130 with probability 0.0010
# Top 5 recommendations for Customer ID CUS-471:
# - PROD-700 with probability 0.8775
# - PROD-587 with probability 0.0618
# - PROD-331 with probability 0.0436
# - PROD-083 with probability 0.0051
# - PROD-447 with probability 0.0028
# Top 5 recommendations for Customer ID CUS-317:
# - PROD-405 with probability 0.9557
# - PROD-747 with probability 0.0159
# - PROD-936 with probability 0.0065
# - PROD-083 with probability 0.0053
# - PROD-331 with probability 0.0043
# Top 5 recommendations for Customer ID CUS-817:
# - PROD-471 with probability 0.9962
# - PROD-156 with probability 0.0014
# - PROD-326 with probability 0.0009
# - PROD-900 with probability 0.0007
# - PROD-083 with probability 0.0004
# Top 5 recommendations for Customer ID CUS-360:
# - PROD-331 with probability 0.9540
# - PROD-838 with probability 0.0206
# - PROD-340 with probability 0.0106
# - PROD-700 with probability 0.0060
# - PROD-303 with probability 0.0016
# Top 5 recommendations for Customer ID CUS-978:
# - PROD-838 with probability 0.9712
# - PROD-377 with probability 0.0088
# - PROD-936 with probability 0.0083
# - PROD-747 with probability 0.0048
# - PROD-340 with probability 0.0013
# Top 5 recommendations for Customer ID CUS-709:
# - PROD-429 with probability 0.9334
# - PROD-936 with probability 0.0262
# - PROD-303 with probability 0.0215
# - PROD-331 with probability 0.0074
# - PROD-377 with probability 0.0030
# Top 5 recommendations for Customer ID CUS-974:
# - PROD-900 with probability 0.9885
# - PROD-377 with probability 0.0027
# - PROD-471 with probability 0.0015
# - PROD-480 with probability 0.0012
# - PROD-326 with probability 0.0010
# Top 5 recommendations for Customer ID CUS-599:
# - PROD-326 with probability 0.9746
# - PROD-018 with probability 0.0147
# - PROD-471 with probability 0.0083
# - PROD-838 with probability 0.0016
# - PROD-079 with probability 0.0001
# Top 5 recommendations for Customer ID CUS-684:
# - PROD-303 with probability 0.9883
# - PROD-405 with probability 0.0033
# - PROD-340 with probability 0.0023
# - PROD-156 with probability 0.0016
# - PROD-429 with probability 0.0013
# Top 5 recommendations for Customer ID CUS-914:
# - PROD-340 with probability 0.8416
# - PROD-429 with probability 0.0475
# - PROD-331 with probability 0.0300
# - PROD-747 with probability 0.0205
# - PROD-303 with probability 0.0157
# Top 5 recommendations for Customer ID CUS-022:
# - PROD-951 with probability 0.9751
# - PROD-018 with probability 0.0099
# - PROD-936 with probability 0.0081
# - PROD-471 with probability 0.0015
# - PROD-405 with probability 0.0014
# Top 5 recommendations for Customer ID CUS-551:
# - PROD-405 with probability 0.9078
# - PROD-331 with probability 0.0486
# - PROD-340 with probability 0.0283
# - PROD-158 with probability 0.0037
# - PROD-156 with probability 0.0035
# Top 5 recommendations for Customer ID CUS-796:
# - PROD-083 with probability 0.9674
# - PROD-331 with probability 0.0220
# - PROD-700 with probability 0.0062
# - PROD-747 with probability 0.0027
# - PROD-997 with probability 0.0010
# Top 5 recommendations for Customer ID CUS-290:
# - PROD-018 with probability 0.9753
# - PROD-951 with probability 0.0067
# - PROD-303 with probability 0.0061
# - PROD-130 with probability 0.0030
# - PROD-198 with probability 0.0028
# Top 5 recommendations for Customer ID CUS-758:
# - PROD-747 with probability 0.9250
# - PROD-331 with probability 0.0227
# - PROD-838 with probability 0.0153
# - PROD-198 with probability 0.0131
# - PROD-340 with probability 0.0122
# Top 5 recommendations for Customer ID CUS-105:
# - PROD-587 with probability 0.9964
# - PROD-156 with probability 0.0028
# - PROD-700 with probability 0.0004
# - PROD-471 with probability 0.0003
# - PROD-326 with probability 0.0002
# Top 5 recommendations for Customer ID CUS-947:
# - PROD-406 with probability 0.9581
# - PROD-340 with probability 0.0122
# - PROD-198 with probability 0.0118
# - PROD-405 with probability 0.0049
# - PROD-018 with probability 0.0047
# Top 5 recommendations for Customer ID CUS-052:
# - PROD-259 with probability 0.9527
# - PROD-331 with probability 0.0286
# - PROD-340 with probability 0.0113
# - PROD-795 with probability 0.0055
# - PROD-303 with probability 0.0005
# Top 5 recommendations for Customer ID CUS-778:
# - PROD-900 with probability 0.9421
# - PROD-429 with probability 0.0430
# - PROD-406 with probability 0.0125
# - PROD-795 with probability 0.0011
# - PROD-340 with probability 0.0005
# Top 5 recommendations for Customer ID CUS-699:
# - PROD-936 with probability 0.9597
# - PROD-377 with probability 0.0139
# - PROD-405 with probability 0.0108
# - PROD-904 with probability 0.0057
# - PROD-130 with probability 0.0039
# Top 5 recommendations for Customer ID CUS-577:
# - PROD-083 with probability 0.9949
# - PROD-303 with probability 0.0013
# - PROD-997 with probability 0.0011
# - PROD-405 with probability 0.0007
# - PROD-079 with probability 0.0006
# Top 5 recommendations for Customer ID CUS-648:
# - PROD-405 with probability 0.9589
# - PROD-377 with probability 0.0080
# - PROD-083 with probability 0.0066
# - PROD-904 with probability 0.0045
# - PROD-480 with probability 0.0032
# Top 5 recommendations for Customer ID CUS-550:
# - PROD-198 with probability 0.9753
# - PROD-018 with probability 0.0107
# - PROD-331 with probability 0.0074
# - PROD-158 with probability 0.0020
# - PROD-083 with probability 0.0012
# Top 5 recommendations for Customer ID CUS-835:
# - PROD-083 with probability 0.9882
# - PROD-838 with probability 0.0027
# - PROD-405 with probability 0.0026
# - PROD-936 with probability 0.0015
# - PROD-303 with probability 0.0011
# Top 5 recommendations for Customer ID CUS-511:
# - PROD-951 with probability 0.9142
# - PROD-838 with probability 0.0649
# - PROD-331 with probability 0.0111
# - PROD-429 with probability 0.0045
# - PROD-303 with probability 0.0037
# Top 5 recommendations for Customer ID CUS-458:
# - PROD-340 with probability 0.9739
# - PROD-700 with probability 0.0220
# - PROD-377 with probability 0.0033
# - PROD-429 with probability 0.0002
# - PROD-747 with probability 0.0002
# Top 5 recommendations for Customer ID CUS-173:
# - PROD-377 with probability 0.9913
# - PROD-904 with probability 0.0037
# - PROD-747 with probability 0.0036
# - PROD-198 with probability 0.0002
# - PROD-700 with probability 0.0002
# Top 5 recommendations for Customer ID CUS-461:
# - PROD-747 with probability 0.9700
# - PROD-838 with probability 0.0086
# - PROD-079 with probability 0.0047
# - PROD-936 with probability 0.0035
# - PROD-904 with probability 0.0019
# Top 5 recommendations for Customer ID CUS-868:
# - PROD-331 with probability 0.9659
# - PROD-083 with probability 0.0114
# - PROD-340 with probability 0.0046
# - PROD-377 with probability 0.0033
# - PROD-900 with probability 0.0028
# Top 5 recommendations for Customer ID CUS-870:
# - PROD-587 with probability 0.9020
# - PROD-700 with probability 0.0952
# - PROD-326 with probability 0.0021
# - PROD-471 with probability 0.0003
# - PROD-156 with probability 0.0002
# Top 5 recommendations for Customer ID CUS-425:
# - PROD-130 with probability 0.9798
# - PROD-018 with probability 0.0048
# - PROD-156 with probability 0.0044
# - PROD-480 with probability 0.0019
# - PROD-198 with probability 0.0019
# Top 5 recommendations for Customer ID CUS-243:
# - PROD-747 with probability 0.9689
# - PROD-377 with probability 0.0120
# - PROD-904 with probability 0.0071
# - PROD-700 with probability 0.0031
# - PROD-198 with probability 0.0015
# Top 5 recommendations for Customer ID CUS-799:
# - PROD-447 with probability 0.9893
# - PROD-480 with probability 0.0028
# - PROD-904 with probability 0.0024
# - PROD-747 with probability 0.0012
# - PROD-018 with probability 0.0009
# Top 5 recommendations for Customer ID CUS-594:
# - PROD-429 with probability 0.9609
# - PROD-340 with probability 0.0309
# - PROD-936 with probability 0.0021
# - PROD-904 with probability 0.0019
# - PROD-795 with probability 0.0013
# Top 5 recommendations for Customer ID CUS-098:
# - PROD-700 with probability 0.9490
# - PROD-587 with probability 0.0372
# - PROD-838 with probability 0.0057
# - PROD-198 with probability 0.0026
# - PROD-340 with probability 0.0015
# Top 5 recommendations for Customer ID CUS-827:
# - PROD-303 with probability 0.9965
# - PROD-838 with probability 0.0013
# - PROD-700 with probability 0.0012
# - PROD-951 with probability 0.0003
# - PROD-156 with probability 0.0003
# Top 5 recommendations for Customer ID CUS-258:
# - PROD-331 with probability 0.9293
# - PROD-340 with probability 0.0579
# - PROD-377 with probability 0.0048
# - PROD-936 with probability 0.0031
# - PROD-405 with probability 0.0029
# Top 5 recommendations for Customer ID CUS-378:
# - PROD-700 with probability 0.8361
# - PROD-587 with probability 0.0806
# - PROD-838 with probability 0.0367
# - PROD-156 with probability 0.0241
# - PROD-480 with probability 0.0058
# Top 5 recommendations for Customer ID CUS-274:
# - PROD-377 with probability 0.9727
# - PROD-340 with probability 0.0143
# - PROD-429 with probability 0.0068
# - PROD-900 with probability 0.0016
# - PROD-331 with probability 0.0008
# Top 5 recommendations for Customer ID CUS-544:
# - PROD-377 with probability 0.9769
# - PROD-587 with probability 0.0083
# - PROD-326 with probability 0.0060
# - PROD-471 with probability 0.0025
# - PROD-900 with probability 0.0015
# Top 5 recommendations for Customer ID CUS-260:
# - PROD-130 with probability 0.9693
# - PROD-700 with probability 0.0061
# - PROD-083 with probability 0.0060
# - PROD-018 with probability 0.0031
# - PROD-587 with probability 0.0021
# Top 5 recommendations for Customer ID CUS-825:
# - PROD-480 with probability 0.9685
# - PROD-156 with probability 0.0107
# - PROD-587 with probability 0.0047
# - PROD-838 with probability 0.0036
# - PROD-471 with probability 0.0027
# Top 5 recommendations for Customer ID CUS-741:
# - PROD-326 with probability 0.9512
# - PROD-377 with probability 0.0410
# - PROD-587 with probability 0.0030
# - PROD-795 with probability 0.0011
# - PROD-900 with probability 0.0010
# Top 5 recommendations for Customer ID CUS-774:
# - PROD-936 with probability 0.9431
# - PROD-951 with probability 0.0386
# - PROD-303 with probability 0.0140
# - PROD-838 with probability 0.0020
# - PROD-018 with probability 0.0005
# Top 5 recommendations for Customer ID CUS-563:
# - PROD-018 with probability 0.9906
# - PROD-198 with probability 0.0041
# - PROD-406 with probability 0.0017
# - PROD-303 with probability 0.0013
# - PROD-130 with probability 0.0009
# Top 5 recommendations for Customer ID CUS-675:
# - PROD-340 with probability 0.9837
# - PROD-405 with probability 0.0151
# - PROD-331 with probability 0.0003
# - PROD-198 with probability 0.0002
# - PROD-936 with probability 0.0001
# Top 5 recommendations for Customer ID CUS-375:
# - PROD-393 with probability 0.9192
# - PROD-838 with probability 0.0746
# - PROD-471 with probability 0.0028
# - PROD-158 with probability 0.0010
# - PROD-951 with probability 0.0004
# Top 5 recommendations for Customer ID CUS-483:
# - PROD-198 with probability 0.9907
# - PROD-018 with probability 0.0030
# - PROD-747 with probability 0.0029
# - PROD-997 with probability 0.0011
# - PROD-083 with probability 0.0004
# Top 5 recommendations for Customer ID CUS-059:
# - PROD-405 with probability 0.9399
# - PROD-340 with probability 0.0534
# - PROD-936 with probability 0.0035
# - PROD-303 with probability 0.0009
# - PROD-130 with probability 0.0009
# Top 5 recommendations for Customer ID CUS-080:
# - PROD-838 with probability 0.9208
# - PROD-331 with probability 0.0699
# - PROD-747 with probability 0.0077
# - PROD-198 with probability 0.0007
# - PROD-951 with probability 0.0002
# Top 5 recommendations for Customer ID CUS-726:
# - PROD-904 with probability 0.9835
# - PROD-377 with probability 0.0125
# - PROD-480 with probability 0.0010
# - PROD-130 with probability 0.0008
# - PROD-447 with probability 0.0007
# Top 5 recommendations for Customer ID CUS-381:
# - PROD-406 with probability 0.9739
# - PROD-587 with probability 0.0060
# - PROD-156 with probability 0.0059
# - PROD-429 with probability 0.0051
# - PROD-900 with probability 0.0044
# Top 5 recommendations for Customer ID CUS-199:
# - PROD-303 with probability 0.9853
# - PROD-018 with probability 0.0142
# - PROD-198 with probability 0.0003
# - PROD-951 with probability 0.0001
# - PROD-130 with probability 0.0000
# Top 5 recommendations for Customer ID CUS-473:
# - PROD-795 with probability 0.9628
# - PROD-587 with probability 0.0134
# - PROD-406 with probability 0.0086
# - PROD-259 with probability 0.0035
# - PROD-900 with probability 0.0030
# Top 5 recommendations for Customer ID CUS-757:
# - PROD-471 with probability 0.9443
# - PROD-393 with probability 0.0074
# - PROD-156 with probability 0.0059
# - PROD-838 with probability 0.0055
# - PROD-747 with probability 0.0051
# Top 5 recommendations for Customer ID CUS-079:
# - PROD-471 with probability 0.9130
# - PROD-083 with probability 0.0180
# - PROD-326 with probability 0.0139
# - PROD-700 with probability 0.0063
# - PROD-018 with probability 0.0062
